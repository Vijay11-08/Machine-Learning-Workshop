# %% [markdown]
# #**Version Control Tool**

# %% [markdown]
# > **A Version Control Tool, Also Known As A Version Control System (VCS) Or Source Code Management (SCM) System**

# %% [markdown]
# > **Helps Track and Manage Changes To Files And Code In A Collaborative Development Environment**
